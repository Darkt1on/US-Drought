# %%
import os
import subprocess
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Preprocessing

# %%
# Read data into a dataframe
df = pd.read_csv(r"dataset/train_timeseries.csv")

# %%
drought_df = df
drought_df.head()
# Out:
#    fips        date  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 0  1001  2000-01-01     0.22  100.51   9.65  14.74   13.51   13.51    20.96
# 1  1001  2000-01-02     0.20  100.55  10.42  16.69   14.71   14.71    22.80
# 2  1001  2000-01-03     3.65  100.15  11.76  18.49   16.52   16.52    22.73
# 3  1001  2000-01-04    15.95  100.29   6.42  11.40    6.09    6.10    18.09
# 4  1001  2000-01-05     0.00  101.15   2.95   3.86   -3.29   -3.20    10.82
#
#    T2M_MIN  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  \
# 0    11.46  ...  14.65   2.20       2.94       1.49         1.46   4.85
# 1    12.61  ...  16.60   2.52       3.43       1.83         1.60   5.33
# 2    15.32  ...  18.41   4.03       5.33       2.66         2.67   7.53
# 3     2.16  ...  11.31   3.84       5.67       2.08         3.59   6.73
# 4    -2.66  ...   2.65   1.60       2.50       0.52         1.98   2.94
#
#    WS50M_MAX  WS50M_MIN  WS50M_RANGE  score
# 0       6.04       3.23         2.81    NaN
# 1       6.13       3.72         2.41    NaN
# 2       9.52       5.87         3.66    NaN
# 3       9.31       3.74         5.58    1.0
# 4       4.85       0.65         4.19    NaN
#
# [5 rows x 21 columns]

# %%
drought_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19300680 entries, 0 to 19300679
# Data columns (total 21 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   fips         int64
#  1   date         object
#  2   PRECTOT      float64
#  3   PS           float64
#  4   QV2M         float64
#  5   T2M          float64
#  6   T2MDEW       float64
#  7   T2MWET       float64
#  8   T2M_MAX      float64
#  9   T2M_MIN      float64
#  10  T2M_RANGE    float64
#  11  TS           float64
#  12  WS10M        float64
#  13  WS10M_MAX    float64
#  14  WS10M_MIN    float64
#  15  WS10M_RANGE  float64
#  16  WS50M        float64
#  17  WS50M_MAX    float64
#  18  WS50M_MIN    float64
#  19  WS50M_RANGE  float64
#  20  score        float64
# dtypes: float64(19), int64(1), object(1)
# memory usage: 3.0+ GB

# %%
# Check null values
drought_df.isnull().sum()
# Out:
# fips                  0
# date                  0
# PRECTOT               0
# PS                    0
# QV2M                  0
# T2M                   0
# T2MDEW                0
# T2MWET                0
# T2M_MAX               0
# T2M_MIN               0
# T2M_RANGE             0
# TS                    0
# WS10M                 0
# WS10M_MAX             0
# WS10M_MIN             0
# WS10M_RANGE           0
# WS50M                 0
# WS50M_MAX             0
# WS50M_MIN             0
# WS50M_RANGE           0
# score          16543884
# dtype: int64

# %%
# Removing the null values in the target variable as the drought score is only available for once in 7 days.
drought_df = drought_df.dropna()
drought_df.isnull().sum()
# Out:
# fips           0
# date           0
# PRECTOT        0
# PS             0
# QV2M           0
# T2M            0
# T2MDEW         0
# T2MWET         0
# T2M_MAX        0
# T2M_MIN        0
# T2M_RANGE      0
# TS             0
# WS10M          0
# WS10M_MAX      0
# WS10M_MIN      0
# WS10M_RANGE    0
# WS50M          0
# WS50M_MAX      0
# WS50M_MIN      0
# WS50M_RANGE    0
# score          0
# dtype: int64

# %%
# Convert date columns into numeric value
drought_df['year'] = pd.DatetimeIndex(drought_df['date']).year
drought_df['month'] = pd.DatetimeIndex(drought_df['date']).month
drought_df['day'] = pd.DatetimeIndex(drought_df['date']).day
drought_df['score'] = drought_df['score'].round().astype(int)
drought_df.dtypes
# Out:
# fips             int64
# date            object
# PRECTOT        float64
# PS             float64
# QV2M           float64
# T2M            float64
# T2MDEW         float64
# T2MWET         float64
# T2M_MAX        float64
# T2M_MIN        float64
# T2M_RANGE      float64
# TS             float64
# WS10M          float64
# WS10M_MAX      float64
# WS10M_MIN      float64
# WS10M_RANGE    float64
# WS50M          float64
# WS50M_MAX      float64
# WS50M_MIN      float64
# WS50M_RANGE    float64
# score            int32
# year             int64
# month            int64
# day              int64
# dtype: object

# %%
drought_df['fips'].nunique()
# Out:
# 3108

# %%
drought_df['score'].round().value_counts()
# Out:
# 0    1652230
# 1     466944
# 2     295331
# 3     196802
# 4     106265
# 5      39224
# Name: score, dtype: int64

# %%
print("\nSkewness: \n", drought_df.skew(axis = 0, skipna = True))
print("\nKurtosis: \n", drought_df.kurtosis(axis = 0, skipna = True))
# Out:
# Skewness:
#  fips          -0.077367
# PRECTOT        4.568803
# PS            -2.132573
# QV2M           0.526605
# T2M           -0.426059
# T2MDEW        -0.302684
# T2MWET        -0.289061
# T2M_MAX       -0.467449
# T2M_MIN       -0.365648
# T2M_RANGE      0.092413
# TS            -0.396537
# WS10M          1.112524
# WS10M_MAX      0.931888
# WS10M_MIN      1.400951
# WS10M_RANGE    1.287969
# WS50M          0.861690
# WS50M_MAX      0.899830
# WS50M_MIN      0.860444
# WS50M_RANGE    1.214403
# score          1.498394
# year          -0.000183
# month         -0.008198
# day            0.006969
# dtype: float64
#
# Kurtosis:
#  fips           -1.100136
# PRECTOT        33.304567
# PS              4.813301
# QV2M           -0.786067
# T2M            -0.554336
# T2MDEW         -0.733896
# T2MWET         -0.758504
# T2M_MAX        -0.508101
# T2M_MIN        -0.446940
# T2M_RANGE      -0.316984
# TS             -0.535722
# WS10M           1.419724
# WS10M_MAX       0.705953
# WS10M_MIN       3.159288
# WS10M_RANGE     2.084432
# WS50M           0.819908
# WS50M_MAX       0.988590
# WS50M_MIN       0.596612
# WS50M_RANGE     2.205205
# score           1.387056
# year           -1.208783
# month          -1.207511
# day            -1.194293
# dtype: float64

# %% [markdown]
# # Discover and Visualize the Data to Gain Insights

# %%
column_list = list(drought_df.columns)
column_list
# Out:
# ['fips',
#  'date',
#  'PRECTOT',
#  'PS',
#  'QV2M',
#  'T2M',
#  'T2MDEW',
#  'T2MWET',
#  'T2M_MAX',
#  'T2M_MIN',
#  'T2M_RANGE',
#  'TS',
#  'WS10M',
#  'WS10M_MAX',
#  'WS10M_MIN',
#  'WS10M_RANGE',
#  'WS50M',
#  'WS50M_MAX',
#  'WS50M_MIN',
#  'WS50M_RANGE',
#  'score']

# %%
for col_name in column_list[2:]:
    plt.figure()
    plt.hist(drought_df[col_name], density = True)
    x_name = col_name
    plt.xlabel(x_name)
    y_name = 'Density'
    plt.ylabel(y_name)
    plt.title('Distribution of {x_name}'.format(x_name=x_name))

# %%
drought_df_measures = drought_df[column_list[2:]]
plt.figure(figsize=(10,40))
for x in (range(1,19)):
    plt.subplot(19,1,x)
    sns.boxplot(x =  drought_df_measures.columns[x-1], data=drought_df_measures)
    x_name = drought_df_measures.columns[x-1]
    plt.title(f'Distribution of {x_name}')         
plt.tight_layout()

# %%
print('Total rows = ',len(drought_df_measures.index))
for i in drought_df_measures.select_dtypes(exclude = ['object']).columns:
    print ('Number of values beyong standard outlier limit in ', i)
    print(len(drought_df_measures[(drought_df_measures[i] > drought_df_measures[i].mean() + 3*drought_df_measures[i].std()) | (drought_df_measures[i] < drought_df_measures[i].mean() - 3*drought_df_measures[i].std())]))
# Out:
# Total rows =  2756796
# Number of values beyong standard outlier limit in  PRECTOT
# 65933
# Number of values beyong standard outlier limit in  PS
# 73197
# Number of values beyong standard outlier limit in  QV2M
# 1
# Number of values beyong standard outlier limit in  T2M
# 4531
# Number of values beyong standard outlier limit in  T2MDEW
# 2023
# Number of values beyong standard outlier limit in  T2MWET
# 1814
# Number of values beyong standard outlier limit in  T2M_MAX
# 3384
# Number of values beyong standard outlier limit in  T2M_MIN
# 6944
# Number of values beyong standard outlier limit in  T2M_RANGE
# 3628
# Number of values beyong standard outlier limit in  TS
# 4762
# Number of values beyong standard outlier limit in  WS10M
# 29954
# Number of values beyong standard outlier limit in  WS10M_MAX
# 23387
# Number of values beyong standard outlier limit in  WS10M_MIN
# 39901
# Number of values beyong standard outlier limit in  WS10M_RANGE
# 35979
# Number of values beyong standard outlier limit in  WS50M
# 23090
# Number of values beyong standard outlier limit in  WS50M_MAX
# 25985
# Number of values beyong standard outlier limit in  WS50M_MIN
# 19569
# Number of values beyong standard outlier limit in  WS50M_RANGE
# 33808
# Number of values beyong standard outlier limit in  score
# 39335

# %%
# Removing outliers with +-3std away from mean
drought_df = drought_df[(drought_df['PRECTOT'] <= drought_df['PRECTOT'].mean() + 3*drought_df['PRECTOT'].std()) &
        (drought_df['PRECTOT'] >= drought_df['PRECTOT'].mean() - 3*drought_df['PRECTOT'].std())]

drought_df = drought_df[(drought_df['PS'] <= drought_df['PS'].mean() + 3*drought_df['PS'].std()) &
        (drought_df['PS'] >= drought_df['PS'].mean() - 3*drought_df['PS'].std())]

drought_df = drought_df[(drought_df['QV2M'] <= drought_df['QV2M'].mean() + 3*drought_df['QV2M'].std()) &
        (drought_df['QV2M'] >= drought_df['QV2M'].mean() - 3*drought_df['QV2M'].std())]

drought_df = drought_df[(drought_df['T2M'] <= drought_df['T2M'].mean() + 3*drought_df['T2M'].std()) &
        (drought_df['T2M'] >= drought_df['T2M'].mean() - 3*drought_df['T2M'].std())]

drought_df = drought_df[(drought_df['T2MDEW'] <= drought_df['T2MDEW'].mean() + 3*drought_df['T2MDEW'].std()) &
        (drought_df['T2MDEW'] >= drought_df['T2MDEW'].mean() - 3*drought_df['T2MDEW'].std())]

drought_df = drought_df[(drought_df['T2MWET'] <= drought_df['T2MWET'].mean() + 3*drought_df['T2MWET'].std()) &
        (drought_df['T2MWET'] >= drought_df['T2MWET'].mean() - 3*drought_df['T2MWET'].std())]

drought_df = drought_df[(drought_df['T2M_MAX'] <= drought_df['T2M_MAX'].mean() + 3*drought_df['T2M_MAX'].std()) &
        (drought_df['T2M_MAX'] >= drought_df['T2M_MAX'].mean() - 3*drought_df['T2M_MAX'].std())]

drought_df = drought_df[(drought_df['T2M_MIN'] <= drought_df['T2M_MIN'].mean() + 3*drought_df['T2M_MIN'].std()) &
        (drought_df['T2M_MIN'] >= drought_df['T2M_MIN'].mean() - 3*drought_df['T2M_MIN'].std())]

drought_df = drought_df[(drought_df['T2M_RANGE'] <= drought_df['T2M_RANGE'].mean() + 3*drought_df['T2M_RANGE'].std()) &
        (drought_df['T2M_RANGE'] >= drought_df['T2M_RANGE'].mean() - 3*drought_df['T2M_RANGE'].std())]

drought_df = drought_df[(drought_df['TS'] <= drought_df['TS'].mean() + 3*drought_df['TS'].std()) &
        (drought_df['TS'] >= drought_df['TS'].mean() - 3*drought_df['TS'].std())]

drought_df = drought_df[(drought_df['WS10M'] <= drought_df['WS10M'].mean() + 3*drought_df['WS10M'].std()) &
        (drought_df['WS10M'] >= drought_df['WS10M'].mean() - 3*drought_df['WS10M'].std())]

drought_df = drought_df[(drought_df['WS10M_MAX'] <= drought_df['WS10M_MAX'].mean() + 3*drought_df['WS10M_MAX'].std()) &
        (drought_df['WS10M_MAX'] >= drought_df['WS10M_MAX'].mean() - 3*drought_df['WS10M_MAX'].std())]

drought_df = drought_df[(drought_df['WS10M_MIN'] <= drought_df['WS10M_MIN'].mean() + 3*drought_df['WS10M_MIN'].std()) &
        (drought_df['WS10M_MIN'] >= drought_df['WS10M_MIN'].mean() - 3*drought_df['WS10M_MIN'].std())]

drought_df = drought_df[(drought_df['WS10M_RANGE'] <= drought_df['WS10M_RANGE'].mean() + 3*drought_df['WS10M_RANGE'].std()) &
        (drought_df['WS10M_RANGE'] >= drought_df['WS10M_RANGE'].mean() - 3*drought_df['WS10M_RANGE'].std())]

drought_df = drought_df[(drought_df['WS50M'] <= drought_df['WS50M'].mean() + 3*drought_df['WS50M'].std()) &
        (drought_df['WS50M'] >= drought_df['WS50M'].mean() - 3*drought_df['WS50M'].std())]

drought_df = drought_df[(drought_df['WS50M_MAX'] <= drought_df['WS50M_MAX'].mean() + 3*drought_df['WS50M_MAX'].std()) &
        (drought_df['WS50M_MAX'] >= drought_df['WS50M_MAX'].mean() - 3*drought_df['WS50M_MAX'].std())]

drought_df = drought_df[(drought_df['WS50M_MIN'] <= drought_df['WS50M_MIN'].mean() + 3*drought_df['WS50M_MIN'].std()) &
        (drought_df['WS50M_MIN'] >= drought_df['WS50M_MIN'].mean() - 3*drought_df['WS50M_MIN'].std())]

drought_df = drought_df[(drought_df['WS50M_RANGE'] <= drought_df['WS50M_RANGE'].mean() + 3*drought_df['WS50M_RANGE'].std()) &
        (drought_df['WS50M_RANGE'] >= drought_df['WS50M_RANGE'].mean() - 3*drought_df['WS50M_RANGE'].std())]

print('Total rows = ',len(drought_df.index))
# Out:
# Total rows =  2276219

# %%
drought_df.head()
# Out:
#     fips        date  PRECTOT      PS  QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 10  1001  2000-01-11     1.33  100.40  6.63  11.48    7.84    7.84    18.88
# 17  1001  2000-01-18     1.11  100.39  9.53  14.28   13.26   13.26    18.04
# 24  1001  2000-01-25     0.00  100.11  2.05  -0.78   -7.93   -7.72     5.65
# 31  1001  2000-02-01     0.00  101.00  3.36   2.06   -1.73   -1.70    11.02
# 38  1001  2000-02-08     0.00  101.04  5.01   8.88    3.90    3.91    17.64
#
#     T2M_MIN  ...  WS10M_MIN  WS10M_RANGE  WS50M  WS50M_MAX  WS50M_MIN  \
# 10     5.72  ...       1.05         1.43   3.55       6.38       1.71
# 17     8.98  ...       1.67         1.92   5.19       6.40       3.84
# 24    -5.46  ...       2.28         2.32   5.75       8.03       3.96
# 31    -4.21  ...       0.88         1.86   4.18       6.38       1.27
# 38     2.65  ...       0.48         1.55   2.74       5.33       0.69
#
#     WS50M_RANGE  score  year  month  day
# 10         4.67      2  2000      1   11
# 17         2.55      2  2000      1   18
# 24         4.07      2  2000      1   25
# 31         5.11      1  2000      2    1
# 38         4.63      1  2000      2    8
#
# [5 rows x 24 columns]

# %%
categorical_column_list = ['score','year','month','day']
drought_df_categorical = drought_df[['score','year','month','day']]

# %%
# Distribution of categorical variables
plt.figure(figsize=(10,40))
for col_name in categorical_column_list:
    plt.figure()
    drought_df_categorical[col_name].value_counts().plot(kind = 'bar')
    x_name = col_name
    y_name = 'Density'
    plt.xlabel(x_name)
    plt.ylabel(y_name)
    plt.title('Distribution of {x_name}'.format(x_name=x_name))
    plt.tight_layout()

# %%
plt.scatter(drought_df['year'], drought_df['score'], c ="blue")
plt.show()

# %%
plt.scatter(drought_df['QV2M'], drought_df['T2M'], c =drought_df['score'])
plt.xlabel('QV2M')
plt.ylabel('T2M')
plt.title('Variation of T2M vs QV2M')
plt.show()

plt.scatter(drought_df['T2M'], drought_df['T2MDEW'], c =drought_df['score'])
plt.xlabel('T2M')
plt.ylabel('T2MDEW')
plt.title('Variation of T2MDEW vs T2M')
plt.show

temp_df = drought_df[drought_df['score']==5]
plt.scatter(drought_df['WS10M'], drought_df['WS50M'], c= drought_df['score'])
plt.xlabel('WS10M')
plt.ylabel('WS50M')
plt.title('Variation of WS50M vs WS10M')
plt.show()

# %%
# Correlation matrix
correlation_plot = drought_df_measures.corr()
correlation_plot.style.background_gradient(cmap = 'RdYlGn')
# Out:
# <style type="text/css">
# #T_d29c8_row0_col0, #T_d29c8_row1_col1, #T_d29c8_row2_col2, #T_d29c8_row3_col3, #T_d29c8_row3_col9, #T_d29c8_row4_col4, #T_d29c8_row4_col5, #T_d29c8_row5_col4, #T_d29c8_row5_col5, #T_d29c8_row6_col6, #T_d29c8_row7_col7, #T_d29c8_row8_col8, #T_d29c8_row9_col3, #T_d29c8_row9_col9, #T_d29c8_row10_col10, #T_d29c8_row11_col11, #T_d29c8_row12_col12, #T_d29c8_row13_col13, #T_d29c8_row14_col14, #T_d29c8_row15_col15, #T_d29c8_row16_col16, #T_d29c8_row17_col17, #T_d29c8_row18_col18 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d29c8_row0_col1, #T_d29c8_row18_col17 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_d29c8_row0_col2, #T_d29c8_row12_col13, #T_d29c8_row16_col13 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_d29c8_row0_col3, #T_d29c8_row15_col8 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_d29c8_row0_col4, #T_d29c8_row0_col5 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_d29c8_row0_col6, #T_d29c8_row7_col18, #T_d29c8_row8_col4, #T_d29c8_row8_col5 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_d29c8_row0_col7, #T_d29c8_row9_col0 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_d29c8_row0_col8, #T_d29c8_row1_col18, #T_d29c8_row2_col14, #T_d29c8_row2_col15, #T_d29c8_row2_col17, #T_d29c8_row4_col10, #T_d29c8_row4_col11, #T_d29c8_row4_col13, #T_d29c8_row4_col14, #T_d29c8_row4_col15, #T_d29c8_row5_col10, #T_d29c8_row5_col11, #T_d29c8_row5_col13, #T_d29c8_row5_col14, #T_d29c8_row5_col15, #T_d29c8_row6_col12, #T_d29c8_row6_col16, #T_d29c8_row8_col0, #T_d29c8_row8_col1, #T_d29c8_row8_col16, #T_d29c8_row11_col3, #T_d29c8_row11_col6, #T_d29c8_row11_col7, #T_d29c8_row11_col9, #T_d29c8_row13_col2, #T_d29c8_row13_col4, #T_d29c8_row13_col5, #T_d29c8_row13_col7, #T_d29c8_row15_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_d29c8_row0_col9, #T_d29c8_row18_col11 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_d29c8_row0_col10, #T_d29c8_row3_col18, #T_d29c8_row8_col13, #T_d29c8_row18_col7 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_d29c8_row0_col11 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_d29c8_row0_col12, #T_d29c8_row12_col8, #T_d29c8_row16_col2 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_d29c8_row0_col13, #T_d29c8_row1_col6, #T_d29c8_row10_col0, #T_d29c8_row17_col0, #T_d29c8_row18_col13 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_d29c8_row0_col14 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_d29c8_row0_col15, #T_d29c8_row6_col18 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_d29c8_row0_col16, #T_d29c8_row10_col8, #T_d29c8_row15_col18, #T_d29c8_row18_col14 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_d29c8_row0_col17, #T_d29c8_row8_col7, #T_d29c8_row9_col18 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_d29c8_row0_col18, #T_d29c8_row1_col11, #T_d29c8_row16_col7 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_d29c8_row1_col0, #T_d29c8_row14_col0 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_d29c8_row1_col2 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_d29c8_row1_col3 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_d29c8_row1_col4, #T_d29c8_row1_col5 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_d29c8_row1_col7, #T_d29c8_row7_col1 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_d29c8_row1_col8, #T_d29c8_row14_col4, #T_d29c8_row14_col5 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_d29c8_row1_col9, #T_d29c8_row3_col0 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_d29c8_row1_col10, #T_d29c8_row1_col15, #T_d29c8_row8_col10, #T_d29c8_row12_col2, #T_d29c8_row12_col4, #T_d29c8_row12_col5 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_d29c8_row1_col12, #T_d29c8_row12_col18 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_d29c8_row1_col13, #T_d29c8_row6_col13, #T_d29c8_row9_col13, #T_d29c8_row12_col6 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_d29c8_row1_col14, #T_d29c8_row8_col14, #T_d29c8_row16_col8 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_d29c8_row1_col16, #T_d29c8_row14_col1 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_d29c8_row1_col17, #T_d29c8_row11_col1, #T_d29c8_row16_col6 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_d29c8_row2_col0, #T_d29c8_row3_col8, #T_d29c8_row9_col8 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_d29c8_row2_col1 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_d29c8_row2_col3, #T_d29c8_row9_col2, #T_d29c8_row13_col11 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_d29c8_row2_col4, #T_d29c8_row4_col2 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_d29c8_row2_col5, #T_d29c8_row5_col2, #T_d29c8_row10_col14 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_d29c8_row2_col6 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_d29c8_row2_col7 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_d29c8_row2_col8, #T_d29c8_row8_col11 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_d29c8_row2_col9, #T_d29c8_row6_col4 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_d29c8_row2_col10, #T_d29c8_row2_col11, #T_d29c8_row2_col13, #T_d29c8_row3_col14, #T_d29c8_row6_col14, #T_d29c8_row10_col3, #T_d29c8_row10_col9, #T_d29c8_row11_col2, #T_d29c8_row11_col4, #T_d29c8_row11_col5, #T_d29c8_row13_col3, #T_d29c8_row15_col3 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_d29c8_row2_col12, #T_d29c8_row9_col12, #T_d29c8_row15_col4, #T_d29c8_row15_col5 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_d29c8_row2_col16, #T_d29c8_row4_col16, #T_d29c8_row5_col16, #T_d29c8_row6_col15, #T_d29c8_row7_col13, #T_d29c8_row9_col15 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_d29c8_row2_col18 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_d29c8_row3_col1, #T_d29c8_row9_col1 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_d29c8_row3_col2, #T_d29c8_row11_col13 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_d29c8_row3_col4, #T_d29c8_row3_col5, #T_d29c8_row5_col3, #T_d29c8_row15_col14 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_d29c8_row3_col6, #T_d29c8_row3_col7, #T_d29c8_row6_col3, #T_d29c8_row7_col3 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_d29c8_row3_col10, #T_d29c8_row7_col10, #T_d29c8_row7_col12, #T_d29c8_row8_col12, #T_d29c8_row9_col16 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_d29c8_row3_col11, #T_d29c8_row6_col11, #T_d29c8_row7_col17 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_d29c8_row3_col12, #T_d29c8_row15_col2 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_d29c8_row3_col13, #T_d29c8_row17_col1 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_d29c8_row3_col15, #T_d29c8_row7_col11, #T_d29c8_row7_col16, #T_d29c8_row10_col2, #T_d29c8_row10_col4, #T_d29c8_row10_col5, #T_d29c8_row17_col4, #T_d29c8_row17_col5, #T_d29c8_row18_col1 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_d29c8_row3_col16, #T_d29c8_row6_col10, #T_d29c8_row7_col15, #T_d29c8_row10_col7, #T_d29c8_row13_col6, #T_d29c8_row14_col9, #T_d29c8_row17_col2 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_d29c8_row3_col17 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_d29c8_row4_col0, #T_d29c8_row5_col0 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_d29c8_row4_col1, #T_d29c8_row5_col1 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_d29c8_row4_col3, #T_d29c8_row7_col2, #T_d29c8_row9_col4, #T_d29c8_row9_col5, #T_d29c8_row10_col15, #T_d29c8_row11_col14, #T_d29c8_row14_col11, #T_d29c8_row15_col10 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_d29c8_row4_col6, #T_d29c8_row5_col6 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_d29c8_row4_col7, #T_d29c8_row5_col7, #T_d29c8_row6_col7, #T_d29c8_row7_col4, #T_d29c8_row12_col16, #T_d29c8_row16_col12 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_d29c8_row4_col8, #T_d29c8_row5_col8 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_d29c8_row4_col9, #T_d29c8_row5_col9 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_d29c8_row4_col1

# %% [markdown]
# Attributes QV2M, T2M, T2MDEW, T2MWET, T2M_MAX, T2M_MIN and TS have shown strong positive correlation
# Similary WS10M, WS10M_MAX and WS10M_MIN have shown a strong positve correlation <br>
# Likewise, WS50M, WS50M_MAX and WS50M_MIN show strong positive correlation <br>
# However, from the scatter plots above, we see significant variance between the data points, despite the strong positive correlation. Hence we'll retain all these variables, and try other feature selection methods.

# %%
print('Total rows = ',len(drought_df.index))

# %% [markdown]
# # Prepare Data for Machine Learning Algorithms

# %%
from pyspark import SparkContext, SparkConf
conf_spark = SparkConf().set("spark.driver.host", "127.0.0.1")
conf_spark = (conf_spark.setMaster('local[*]')
        .set('spark.executor.memory', '4G')
        .set('spark.driver.memory', '45G')
        .set('spark.driver.maxResultSize', '10G'))
sc = SparkContext(conf=conf_spark)

# %%
from pyspark.sql import SparkSession
spark = (SparkSession.builder.master("local[*]").appName('Final_Project').getOrCreate())
sc=spark.sparkContext

# %%
df_spark = spark.createDataFrame(drought_df)

# %%
from pyspark.ml.feature import VectorAssembler, StandardScaler 
assembler = VectorAssembler(inputCols = df_spark.columns[2:20], outputCol="features")
output = assembler.transform(df_spark)
final_data = output.select("features","score")

# %%
scaler = StandardScaler(inputCol="features", outputCol="scaled_features")
final_data_scaled = scaler.fit(final_data).transform(final_data)
# Out:
# 22/12/06 01:53:02 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 22/12/06 01:53:04 WARN TaskSetManager: Stage 0 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.

# %%
train_data, test_data = final_data_scaled.randomSplit([0.7,0.3], seed = 42)

# %%
from pyspark.ml.classification import RandomForestClassifier
rf = RandomForestClassifier(numTrees=3, maxDepth=2, labelCol="score", seed=42)
model = rf.fit(train_data)

# FEATURE IMPORTANCES
model.featureImportances
# Out:
# 22/12/06 01:59:55 WARN TaskSetManager: Stage 9 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:00:35 WARN TaskSetManager: Stage 11 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:00:38 WARN TaskSetManager: Stage 12 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:01:11 WARN TaskSetManager: Stage 13 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:01:37 WARN TaskSetManager: Stage 15 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:02:01 WARN TaskSetManager: Stage 17 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [19], line 7
#       5 # FEATURE IMPORTANCES
#       6 model.featureImportances
# ----> 7 SparseVector(1, {0: 1.0})
#
# NameError: name 'SparseVector' is not defined

# %%
from pyspark.ml.classification import DecisionTreeClassifier
dtc = DecisionTreeClassifier(featuresCol="features", labelCol="score")
dtc = dtc.fit(train_data)

pred = dtc.transform(test_data)
pred.show(3)
# Out:
# 22/12/06 02:09:38 WARN TaskSetManager: Stage 19 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:10:21 WARN TaskSetManager: Stage 21 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:10:29 WARN TaskSetManager: Stage 22 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:10:49 WARN TaskSetManager: Stage 23 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:11:18 WARN TaskSetManager: Stage 25 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:11:59 WARN TaskSetManager: Stage 27 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:12:06 WARN TaskSetManager: Stage 29 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:12:08 WARN TaskSetManager: Stage 31 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:12:08 WARN TaskSetManager: Stage 33 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:12:10 WARN TaskSetManager: Stage 35 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 35:>                                                         (0 + 1) / 1]
# +--------------------+-----+--------------------+--------------------+--------------------+----------+
# |            features|score|     scaled_features|       rawPrediction|         probability|prediction|
# +--------------------+-----+--------------------+--------------------+--------------------+----------+
# |[0.0,80.14,2.85,8...|    2|[0.0,18.298261322...|[200034.0,68677.0...|[0.53460440652961...|       0.0|
# |[0.0,80.14,3.54,2...|    2|[0.0,18.298261322...|[50443.0,27625.0,...|[0.38360862687838...|       0.0|
# |[0.0,80.14,4.15,1...|    2|[0.0,18.298261322...|[200034.0,68677.0...|[0.53460440652961...|       0.0|
# +--------------------+-----+--------------------+--------------------+--------------------+----------+
# only showing top 3 rows

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
f1_evaluator=MulticlassClassificationEvaluator(metricName='f1').setLabelCol("score")
acc_evaluator=MulticlassClassificationEvaluator(metricName='accuracy').setLabelCol("score")
f1 = f1_evaluator.evaluate(pred)
acc = acc_evaluator.evaluate(pred)
print(f1)
print(acc)
# Out:
# 22/12/06 02:30:22 WARN TaskSetManager: Stage 40 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# 22/12/06 02:31:19 WARN TaskSetManager: Stage 42 contains a task of very large size (56984 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 42:==================================================>       (7 + 1) / 8]
# 0.46047018362838343
# 0.6046616918238485

# %%
df_spark.columns[2:20]

# %%
# Significance of each feature in the model
dtc.featureImportances
